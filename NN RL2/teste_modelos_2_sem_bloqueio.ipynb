# %%
from environment import NormalMoveEnv
from experiment import Trajectory
from nn import BetaModel, Model, GeneralModel
from rl import Agent

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Env

# %%
wall=[[9.9,-1.],[10., 1.]]
goal=[[-10.,9.],[-9.,10.]]
env = NormalMoveEnv(goal=goal, wall=wall)

# %% [markdown]
# # RL Model

# %%
m = Model(env, k=2, lr=1e-5, momentum=.9)
a = Agent(env, model=m)
a.episode(size_limit=None)
a.plot()
print(f'Trajectory size: {a.trajectory.run.size}')
# Out:
# Trajectory size: 384

# %%
m = GeneralModel(env, k=2, lr=1e-6, momentum=.9)
a = Agent(env, model=m)
a.episode(size_limit=None)
a.plot(params=True)
print(f'Trajectory size: {a.trajectory.run.size}')
# Out:
# Trajectory size: 432
