# %% [markdown]
# $ \theta = \{\psi, \sigma, \tau\} $

# %% [markdown]
# $\psi$: Parametros para definição do modelo que será utilizado em cada estado<br>
# $\sigma$: Parametros 1 para cada Modelo $\{\sigma_1, \sigma_2, ...\}$ <br>
# $\tau$: Parametros 2 para cada Modelo $\{\tau_1, \tau_2, ...\}$ <br>

# %% [markdown]
# $ \beta: S \mapsto [0,1]^k \;\; onde \;\; k = |\sigma|$ <br>
# $ \beta(s; \psi)_i = p_{\psi}(\sigma_i | s) \; \forall \; i \in (1, 2, ..., k)$ <br>
# A função $ \beta $ define a probabilidade de cada parametro em $ \sigma $ ser o modelo utilizado pra gerar a transição em um estado <br>

# %% [markdown]
# $\mu: S \times S \times A \times \sigma \times \tau \mapsto [0,1] $ <br>
# $\mu(s', s, a, \sigma_x, \tau_x)= p_{\sigma_x,\tau_x}(s'|s,a)$ <br>
# A função $ \mu $ define a probabilidade de transição para um estado, dado um par de estado e ação, seguindo o modelo $\sigma_x$ e $\tau_x$ <br>

# %% [markdown]
# $p_{\theta}(s_{t+1}|s_t, a_t) = \mu(s_{t+1}, s_t, a_t, \sigma_1, \tau_1) \; \times \; \beta(s_t)_1 + \mu(s_{t+1}, s_t, a_t, \sigma_2, \tau_2) \; \times \; \beta(s_t)_2 + ...$

# %% [markdown]
# $p_{\theta}(s_{t+1}|s_t, a_t) = \sum_{i=1}^k \mu(s_{t+1}, s_t, a_t, \sigma_i, \tau_i) \beta(s_t)_i \;\;\;\;\; for \;\; k = |\sigma_{\theta}|$

# %% [markdown]
# $\mu: S \times S \times A \times \sigma_{\theta} \times \tau_{\theta} \mapsto [0,1]; \;\; \mu(s', s, a, \sigma, \tau) = pdf(s'_x, (s_x+(a_x \times \tau)), \sigma) \; \times \; pdf(s'_y, (s_y+ (a_y \times \tau)), \sigma)$

# %% [markdown]
# $\cal{L}[\xi | \theta] = \sum_{t=0}^{\mathrm{T}-1} log \; p_{\theta}(s_{t+1}|s_t, a_t)$

# %%
from environment import NormalMoveEnv
from experiment import Trajectory
from nn import BetaModel, Model
from rl import Agent

import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # RL Model

# %%
env = NormalMoveEnv()
a = Agent(env, lr=1e-7)
a.train(episodes=10, epochs=1000)
a.model.plot()
# Out:
# <AxesSubplot: >

# %%
a.train(episodes=100, epochs=100)
a.model.plot()
# Out:
# <AxesSubplot: >

# %%
a.train(episodes=100, epochs=1000)
a.model.plot()
# Out:
# <AxesSubplot: >

# %%
print(torch.exp(a.model.sigmas))
print(a.model.taus)
print(a.model.model(torch.tensor([[0.,0.], [9.,9.]]).type(torch.DoubleTensor)))
# Out:
# tensor([0.3031, 0.0049], dtype=torch.float64, grad_fn=<ExpBackward0>)
# Parameter containing:
# tensor([1.0338, 0.4990], dtype=torch.float64, requires_grad=True)
# tensor([[7.9077e-01, 2.0923e-01],
#         [8.0991e-05, 9.9992e-01]], dtype=torch.float64,
#        grad_fn=<SoftmaxBackward0>)

# %%
a.plot()
# Out:
# <AxesSubplot: >

# %%
a.Q
# Out:
# array([[[ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [-3.00000e-01,  0.00000e+00, -3.00000e-01,  0.00000e+00],
#         [-3.00000e-01, -3.00000e+02, -3.00000e-01, -3.00000e-01],
#         ...,
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00]],
#
#        [[ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [-5.10000e-01, -3.00000e-01, -5.10000e-01,  0.00000e+00],
#         [-7.38000e-01, -3.00438e+02, -6.57000e-01, -5.10000e-01],
#         ...,
#         [-3.00000e-01,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00]],
#
#        [[-3.00000e-01,  0.00000e+00, -3.00000e-01,  0.00000e+00],
#         [ 0.00000e+00, -5.10000e-01, -5.10000e-01, -3.00000e-01],
#         [-6.57000e-01, -8.91090e-01, -3.00000e-01, -3.00000e-01],
#         ...,
#         [-3.00000e-01,  0.00000e+00,  0.00000e+00, -3.00000e-01],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00]],
#
#        ...,
#
#        [[ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [-3.00000e-01, -5.10000e-01, -3.00000e-01, -3.00000e+02],
#         [-3.00000e-01,  0.00000e+00,  0.00000e+00, -3.00000e-01],
#         ...,
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00]],
#
#        [[ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [-3.00000e-01, -3.00000e-01,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00, -3.00000e-01],
#         ...,
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00]],
#
#        [[ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00, -3.00000e+02],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         ...,
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00],
#         [ 0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00]]])
